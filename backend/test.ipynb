# %%
import sys
sys.path.insert(0, '/home/ari/Documents/final_capstone')

# %load_ext autoreload
# %autoreload 2

# %%
import database_management

# %%
database_management.ingest_sensor_data(
    import_folder_path="/home/ari/Documents/carbon_fiber/OneDrive_1_11-24-2025 copy/split_data_0.25_crush",
    classification_label="0.25crushcore"
)
# Out:
# ...
# SENSOR DATA INGESTION PIPELINE
# ...
# Import folder: /home/ari/Documents/carbon_fiber/OneDrive_1_11-24-2025 copy/split_data_0.25_crush
# Classification: 0.25crushcore
# Output (raw): /home/ari/Documents/final_capstone/backend/raw_database/split_data_0.25_crush
# Output (processed): /home/ari/Documents/final_capstone/backend/database/0.25crushcore
# ...
#
# [STEP 1] Copying raw data to raw_database/...
# ⚠ Warning: split_data_0.25_crush already exists in raw_database/
#   Skipping copy to avoid overwriting.
# Found 48 CSV files to process
#
# [STEP 2] Auto-detecting CSV structure with GPT-5.1...
# ...
# ✓ Detected structure:
#   - Skip rows: 1
#   - Time column: 0
#   - Values column: 1
#   - Values label: Current (pA)
# ...
#
# [STEP 3] Checking existing database files...
# ✓ Found 144 existing files
#   Append mode: Starting from chunk 145
#
# [STEP 4] Processing CSV files into chunks...
# ...
# [OK] Processed: cycle_005.csv (3 chunks)
# [OK] Processed: cycle_012.csv (3 chunks)
# ...
