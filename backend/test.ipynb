# %%
import sys
sys.path.insert(0, '/home/ari/Documents/final_capstone')

# %load_ext autoreload
# %autoreload 2

# %%
from database_management import ingest_sensor_data

# %%
ingest_sensor_data(  # pyright: ignore[reportUndefinedVariable]
    import_folder_path="/home/ari/Documents/carbon_fiber/OneDrive_1_11-24-2025 copy/split_data_0.75_crushcore",
    classification_label="0.75crushcore"
)
# Out:
# ...
# SENSOR DATA INGESTION PIPELINE
# ...
# Import folder: /home/ari/Documents/carbon_fiber/OneDrive_1_11-24-2025 copy/split_data_0.75_crushcore
# Classification: 0.75crushcore
# Output (raw): /home/ari/Documents/final_capstone/backend/raw_database/split_data_0.75_crushcore
# Output (processed): /home/ari/Documents/final_capstone/backend/database/0.75crushcore
# ...
#
# [STEP 1] Copying raw data to raw_database/...
# ✓ Copied to: /home/ari/Documents/final_capstone/backend/raw_database/split_data_0.75_crushcore
#
# Found 31 CSV files to process
#
# [STEP 2] Auto-detecting CSV structure with GPT-5.1...
# ...
# ✓ Detected structure:
#   - Skip rows: 1
#   - Time column: 0
#   - Values column: 1
#   - Values label: Current (pA)
# ...
#
# [STEP 3] Checking existing database files...
# [STEP 4] Processing CSV files into chunks...
# ...
# [OK] Processed: cycle_005.csv (3 chunks)
# [OK] Processed: cycle_012.csv (3 chunks)
# [OK] Processed: cycle_030.csv (3 chunks)
# [OK] Processed: cycle_001.csv (3 chunks)
# ...

# %%
from training import run_cnn, run_resnet

# Trains, captures output, generates PDF report with LLM analysis
result = run_cnn(
    paths=['/home/ari/Documents/carbon_fiber/database/crushcore_0.75', '/home/ari/Documents/carbon_fiber/database/disbond_0.75'],
    save_dir='./models/cnn9_experiment',
    use_llm=True,
)

# Access everything
print(result.training_result.test_accuracy)
print(result.training_log)        # Captured terminal output
print(result.report_path)         # Path to PDF
# Out:
# 2025-11-28 20:56:31.324768: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/ari/Documents/final_capstone/backend/.venv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# ...
# TRAINING RUN: CNN
# Save directory: ./models/cnn9_experiment
# Timestamp: 2025-11-28T20:56:34.676068
# ...
#
#
# ...
# CNN TRAINING PIPELINE
# ...
# Phase 1: Data Preparation
# ...
# Time period: 10s
# Sampling rate: 1600 Hz
# ...

# %%
from training import run_cnn, run_resnet

# Trains, captures output, generates PDF report with LLM analysis
result = run_resnet(
    paths=['/home/ari/Documents/carbon_fiber/database/crushcore_0.75', '/home/ari/Documents/carbon_fiber/database/disbond_0.75'],
    save_dir='./models/resnt_0.75',
    use_llm=True,
)

# Access everything
print(result.training_result.test_accuracy)
print(result.training_log)        # Captured terminal output
print(result.report_path)         # Path to PDF
# Out:
# 2025-11-28 21:18:10.364034: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/ari/Documents/final_capstone/backend/.venv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# ...
# TRAINING RUN: ResNet
# Save directory: ./models/resnt_0.75
# Timestamp: 2025-11-28T21:18:13.660368
# ...
#
#
# ...
# RESNET TRAINING PIPELINE
# ...
# Phase 1: Data Preparation
# ...
# Time period: 10s
# Sampling rate: 1600 Hz
# ...
